# %%
#Do not disrespect me than come at me maliciously acting like you want good for me!
#I don't seek sympathy nor I need your jealous arses to get on top. I'm top!
import matplotlib.pyplot as pyplot

#Set up the data
labels = ('PHP', 'CSS', 'HTML', 'Python', 'Java')
index = (1, 2, 3, 4, 5)
sizes = [50, 21, 18, 16, 5]

#Set up the bar chart
pyplot.bar(index, sizes, tick_label=labels)

# Configure the layout
pyplot.ylabel('Usage')
pyplot.xlabel('Programming Languages')

# Display the chart
pyplot.show()
